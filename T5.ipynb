# %%
import torch
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
import re
import spacy

# Load pre-trained transformer model for summarization
tokenizer = AutoTokenizer.from_pretrained("t5-base")
model = AutoModelForSeq2SeqLM.from_pretrained("t5-base")
summarization_pipeline = pipeline("summarization", model=model, tokenizer=tokenizer)

# Load spaCy for PII detection and redaction
nlp = spacy.load("en_core_web_sm")

def redact_pii(text):
    # Function to redact PII (Personal Identifiable Information) from text
    doc = nlp(text)
    redacted_text = text
    for ent in doc.ents:
        if ent.label_ in ["PERSON", "NORP", "ORG", "GPE", "DATE", "TIME", "CARDINAL", "QUANTITY"]:
            redacted_text = redacted_text.replace(ent.text, "<REDACTED>")
    return redacted_text

def summarize_and_redact(text):
    # Summarize the text
    summarized_text = summarization_pipeline(text, max_length=5000, min_length=30, do_sample=False)[0]['summary_text']
    # Redact PII from the summarized text
    redacted_summarized_text = redact_pii(summarized_text)
    return redacted_summarized_text

# Example usage
input_text = """

"""

redacted_summary = summarize_and_redact(input_text)
print(redacted_summary)
# Out:
# 2024-04-26 20:12:25.113802: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/localadmin/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/localadmin/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /Users/localadmin/anaconda3/lib/python3.11/site-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (834 > 512). Running this sequence through the model will result in indexing errors
# Your max_length is set to 5000, but your input_length is only 834. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=417)
# quality control in the pharmaceutical industry aims to verify and test the medicine at various stages of production to ensure every product is of the highest quality . quality assurance is the process of making sure quality requirements have been fulfilled . type I borosilicate glass is used for laboratory glass apparatus, water for injection and for parenteral and non-parenteral use . Type III regular soda-lime glass is fairly resistant to attack by water .

# %%
pip install fitz
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting fitz
#   Obtaining dependency information for fitz from https://files.pythonhosted.org/packages/7e/28/27f27d66eb82f24e6595deb26c0a875e62431878c416e38eac515023abb2/fitz-0.0.1.dev2-py2.py3-none-any.whl.metadata
#   Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl.metadata (816 bytes)
# Collecting configobj (from fitz)
#   Obtaining dependency information for configobj from https://files.pythonhosted.org/packages/d3/bb/d10e531b297dd1d46f6b1fd11d018247af9f2d460037554bb7bb9011c6ac/configobj-5.0.8-py2.py3-none-any.whl.metadata
#   Downloading configobj-5.0.8-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting configparser (from fitz)
#   Obtaining dependency information for configparser from https://files.pythonhosted.org/packages/a8/20/f4aab9a42378542295c3be2bbdab353de10eb95396f6d4a5bc7a21b00952/configparser-7.0.0-py3-none-any.whl.metadata
#   Downloading configparser-7.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting httplib2 (from fitz)
#   Obtaining dependency information for httplib2 from https://files.pythonhosted.org/packages/a8/6c/d2fbdaaa5959339d53ba38e94c123e4e84b8fbc4b84beb0e70d7c1608486/httplib2-0.22.0-py3-none-any.whl.metadata
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting nibabel (from fitz)
#   Obtaining dependency information for nibabel from https://files.pythonhosted.org/packages/77/3f/ce43b8c2ccc4a7913a87c4d425aaf0080ea3abf947587e47dc2025981a17/nibabel-5.2.1-py3-none-any.whl.metadata
#   Downloading nibabel-5.2.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting nipype (from fitz)
#   Obtaining dependency information for nipype from https://files.pythonhosted.org/packages/60/02/d4e8c990e14d7efcb35038a3d1743ff5068d66d92c1fcc298c9654bae55d/nipype-1.8.6-py3-none-any.whl.metadata
#   Downloading nipype-1.8.6-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from fitz) (1.24.4)
# Requirement already satisfied: pandas in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from fitz) (2.2.1)
# Collecting pyxnat (from fitz)
#   Obtaining dependency information for pyxnat from https://files.pythonhosted.org/packages/97/f6/dbe92707b35f3fec297228e81cbf35e0b1028e20c98a0cea1650e967f88a/pyxnat-1.6.2-py3-none-any.whl.metadata
#   Downloading pyxnat-1.6.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: scipy in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from fitz) (1.12.0)
# Requirement already satisfied: six in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from configobj->fitz) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from httplib2->fitz) (3.0.9)
# Requirement already satisfied: packaging>=17 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from nibabel->fitz) (23.2)
# Requirement already satisfied: click>=6.6.0 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from nipype->fitz) (8.0.4)
# Requirement already satisfied: networkx>=2.0 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from nipype->fitz) (3.1)
# Collecting prov>=1.5.2 (from nipype->fitz)
#   Obtaining dependency information for prov>=1.5.2 from https://files.pythonhosted.org/packages/cf/8d/9a5110845c6b117d203e3ca9eec5ee79bed29cef508c8415fbc85e900150/prov-2.0.0-py3-none-any.whl.metadata
#   Downloading prov-2.0.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting pydot>=1.2.3 (from nipype->fitz)
#   Obtaining dependency information for pydot>=1.2.3 from https://files.pythonhosted.org/packages/7f/90/c9b51f3cdff89cd8f93382060330f43d1af098a6624cff439e700791e922/pydot-2.0.0-py3-none-any.whl.metadata
#   Downloading pydot-2.0.0-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from nipype->fitz) (2.8.2)
# Collecting rdflib>=5.0.0 (from nipype->fitz)
#   Obtaining dependency information for rdflib>=5.0.0 from https://files.pythonhosted.org/packages/d4/b0/7b7d8b5b0d01f1a0b12cc2e5038a868ef3a15825731b8a0d776cf47566c0/rdflib-7.0.0-py3-none-any.whl.metadata
#   Downloading rdflib-7.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting simplejson>=3.8.0 (from nipype->fitz)
#   Obtaining dependency information for simplejson>=3.8.0 from https://files.pythonhosted.org/packages/bc/eb/2bd4a6ec98329158f6855520596e9f2e521e2239e292d43fe1c58cf83a9b/simplejson-3.19.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading simplejson-3.19.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.1 kB)
# Collecting traits!=5.0,<6.4,>=4.6 (from nipype->fitz)
#   Downloading traits-6.3.2.tar.gz (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 24.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock>=3.0.0 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from nipype->fitz) (3.9.0)
# Collecting etelemetry>=0.2.0 (from nipype->fitz)
#   Obtaining dependency information for etelemetry>=0.2.0 from https://files.pythonhosted.org/packages/83/27/f997c9da0e179986fadd6c8474d16743f1b3697c129c2fcd1e739cd038c2/etelemetry-0.3.1-py3-none-any.whl.metadata
#   Downloading etelemetry-0.3.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting looseversion (from nipype->fitz)
#   Obtaining dependency information for looseversion from https://files.pythonhosted.org/packages/4e/74/d5405b9b3b12e9176dff223576d7090bc161092878f533fd0dc23dd6ae1d/looseversion-1.3.0-py2.py3-none-any.whl.metadata
#   Downloading looseversion-1.3.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from pandas->fitz) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from pandas->fitz) (2023.3)
# Requirement already satisfied: lxml>=4.3 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from pyxnat->fitz) (4.9.3)
# Requirement already satisfied: requests>=2.20 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from pyxnat->fitz) (2.31.0)
# Requirement already satisfied: pathlib>=1.0 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from pyxnat->fitz) (1.0.1)
# Collecting ci-info>=0.2 (from etelemetry>=0.2.0->nipype->fitz)
#   Obtaining dependency information for ci-info>=0.2 from https://files.pythonhosted.org/packages/13/c3/8ac768b389d5b6dda1c3ce7992b3acd2b46401f9b71439123858b17b1a2c/ci_info-0.3.0-py3-none-any.whl.metadata
#   Downloading ci_info-0.3.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib>=5.0.0->nipype->fitz)
#   Obtaining dependency information for isodate<0.7.0,>=0.6.0 from https://files.pythonhosted.org/packages/b6/85/7882d311924cbcfc70b1890780763e36ff0b140c7e51c110fc59a532f087/isodate-0.6.1-py2.py3-none-any.whl.metadata
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from requests>=2.20->pyxnat->fitz) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from requests>=2.20->pyxnat->fitz) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from requests>=2.20->pyxnat->fitz) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from requests>=2.20->pyxnat->fitz) (2024.2.2)
# Downloading fitz-0.0.1.dev2-py2.py3-none-any.whl (20 kB)
# Downloading configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Downloading configparser-7.0.0-py3-none-any.whl (16 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 5.1 MB/s eta 0:00:00
# Downloading nibabel-5.2.1-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 21.6 MB/s eta 0:00:0000:0100:01
# Downloading nipype-1.8.6-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 18.4 MB/s eta 0:00:0000:0100:01
# Downloading pyxnat-1.6.2-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.6/95.6 kB 3.9 MB/s eta 0:00:00
# Downloading etelemetry-0.3.1-py3-none-any.whl (6.4 kB)
# Downloading prov-2.0.0-py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 13.2 MB/s eta 0:00:00
# Downloading pydot-2.0.0-py3-none-any.whl (22 kB)
# Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 16.6 MB/s eta 0:00:00
# Downloading simplejson-3.19.2-cp311-cp311-macosx_10_9_x86_64.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 3.7 MB/s eta 0:00:00
# Downloading looseversion-1.3.0-py2.py3-none-any.whl (8.2 kB)
# Downloading ci_info-0.3.0-py3-none-any.whl (7.8 kB)
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 1.1 MB/s eta 0:00:00
# Building wheels for collected packages: traits
#   Building wheel for traits (setup.py) ... done
#   Created wheel for traits: filename=traits-6.3.2-cp311-cp311-macosx_10_9_x86_64.whl size=4999369 sha256=725126075d5d626b4b4f786fb4ed08a0b300ba9c2d31cb4e7801f52511e412a3
#   Stored in directory: /Users/localadmin/Library/Caches/pip/wheels/eb/95/6e/3d5c21d6b340b7b64a86b7926293decf7f6991f67f914819ae
# Successfully built traits
# Installing collected packages: looseversion, traits, simplejson, pydot, nibabel, isodate, httplib2, configparser, configobj, ci-info, rdflib, pyxnat, etelemetry, prov, nipype, fitz
# Successfully installed ci-info-0.3.0 configobj-5.0.8 configparser-7.0.0 etelemetry-0.3.1 fitz-0.0.1.dev2 httplib2-0.22.0 isodate-0.6.1 looseversion-1.3.0 nibabel-5.2.1 nipype-1.8.6 prov-2.0.0 pydot-2.0.0 pyxnat-1.6.2 rdflib-7.0.0 simplejson-3.19.2 traits-6.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install frontend
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting frontend
#   Obtaining dependency information for frontend from https://files.pythonhosted.org/packages/98/02/a9c4713b26ae11464ac334b59504ef6fe66e2c323ee44520ca1cd6dc4929/frontend-0.0.3-py3-none-any.whl.metadata
#   Downloading frontend-0.0.3-py3-none-any.whl.metadata (847 bytes)
# Collecting starlette>=0.12.0 (from frontend)
#   Obtaining dependency information for starlette>=0.12.0 from https://files.pythonhosted.org/packages/fd/18/31fa32ed6c68ba66220204ef0be798c349d0a20c1901f9d4a794e08c76d8/starlette-0.37.2-py3-none-any.whl.metadata
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting uvicorn>=0.7.1 (from frontend)
#   Obtaining dependency information for uvicorn>=0.7.1 from https://files.pythonhosted.org/packages/73/f5/cbb16fcbe277c1e0b8b3ddd188f2df0e0947f545c49119b589643632d156/uvicorn-0.29.0-py3-none-any.whl.metadata
#   Downloading uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: itsdangerous>=1.1.0 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from frontend) (2.0.1)
# Requirement already satisfied: aiofiles in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from frontend) (22.1.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from starlette>=0.12.0->frontend) (3.5.0)
# Requirement already satisfied: click>=7.0 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from uvicorn>=0.7.1->frontend) (8.0.4)
# Requirement already satisfied: h11>=0.8 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from uvicorn>=0.7.1->frontend) (0.14.0)
# Requirement already satisfied: idna>=2.8 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.4.0->starlette>=0.12.0->frontend) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/localadmin/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.4.0->starlette>=0.12.0->frontend) (1.2.0)
# Downloading frontend-0.0.3-py3-none-any.whl (32 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 2.7 MB/s eta 0:00:00
# Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: uvicorn, starlette, frontend
# Successfully installed frontend-0.0.3 starlette-0.37.2 uvicorn-0.29.0
# Note: you may need to restart the kernel to use updated packages.
